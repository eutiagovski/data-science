# %% [markdown]
# ## Imports & Configs

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re # para mexer com regexp

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = stopwords.words('english')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import tensorflow as tf

device_name = tf.test.gpu_device_name()

if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Loading data

# %%
# function to download the book from gutenberg's project
import urllib.request as urllib2

def gutenberg_download(link):
  ### https://www.gutenberg.org/

  start_string = ' START OF THE PROJECT GUTENBERG EBOOK '
  end_string = ' END OF THE PROJECT GUTENBERG EBOOK '
  data = urllib2.urlopen(link) 
  text = (data.read()).decode('utf-8')
  
  cut_start = text.find(start_string)+len(start_string)
  cut_end = text.find(end_string)+len(end_string)

  text = text[cut_start:cut_end]
  return text

# %%
books = [
  {"Alice’s Adventures in Wonderland":'https://www.gutenberg.org/files/11/11-0.txt'},
  {'Pride and Prejudice by Jane Austen': 'https://www.gutenberg.org/files/1342/1342-0.txt'},
  {'Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley': 'https://www.gutenberg.org/files/84/84-0.txt'},
  {'The Adventures of Sherlock Holmes by Arthur Conan Doyle':'https://www.gutenberg.org/files/1661/1661-0.txt'},
  {"Robert's Rules of Order by Henry M. Robert": 'https://www.gutenberg.org/cache/epub/9097/pg9097.txt'}
]

# %%
df_books = pd.DataFrame(columns=['title', 'link', 'text'])

for i in books:
  item = list(i.items())[0]

  df_books = df_books.append({'title': item[0], 'link': item[1], 'text': gutenberg_download(item[1])}, ignore_index=True)

df_books
# Out:
#                                                title  \
# 0                   Alice’s Adventures in Wonderland
# 1                 Pride and Prejudice by Jane Austen
# 2  Frankenstein; Or, The Modern Prometheus by Mar...
# 3  The Adventures of Sherlock Holmes by Arthur Co...
# 4         Robert's Rules of Order by Henry M. Robert
#
#                                                 link  \
# 0        https://www.gutenberg.org/files/11/11-0.txt
# 1    https://www.gutenberg.org/files/1342/1342-0.txt
# 2        https://www.gutenberg.org/files/84/84-0.txt
# 3    https://www.gutenberg.org/files/1661/1661-0.txt
# 4  https://www.gutenberg.org/cache/epub/9097/pg90...
#
#                                                 text
# 0  ALICE’S ADVENTURES IN WONDERLAND ***\r\n\r\n[I...
# 1  PRIDE AND PREJUDICE ***\r\n\r\n\r\n\r\n\r\nTHE...
# 2  FRANKENSTEIN ***\r\n\r\n\r\n\r\n\r\nFrankenste...
# 3  THE ADVENTURES OF SHERLOCK HOLMES ***\r\n\r\nc...
# 4  ROBERT’S RULES OF ORDER ***\r\n\r\n\r\n\r\n\r\...

# %%
df_books.text[0]
# Out:
# 'ALICE’S ADVENTURES IN WONDERLAND ***\r\n\r\n[Illustration]\r\n\r\n\r\n\r\n\r\nAlice’s Adventures in Wonderland\r\n\r\nby Lewis Carroll\r\n\r\nTHE MILLENNIUM FULCRUM EDITION 3.0\r\n\r\nContents\r\n\r\n CHAPTER I.     Down the Rabbit-Hole\r\n CHAPTER II.    The Pool of Tears\r\n CHAPTER III.   A Caucus-Race and a Long Tale\r\n CHAPTER IV.    The Rabbit Sends in a Little Bill\r\n CHAPTER V.     Advice from a Caterpillar\r\n CHAPTER VI.    Pig and Pepper\r\n CHAPTER VII.   A Mad Tea-Party\r\n CHAPTER VIII.  The Queen’s Croquet-Ground\r\n CHAPTER IX.    The Mock Turtle’s Story\r\n CHAPTER X.     The Lobster Quadrille\r\n CHAPTER XI.    Who Stole the Tarts?\r\n CHAPTER XII.   Alice’s Evidence\r\n\r\n\r\n\r\n\r\nCHAPTER I.\r\nDown the Rabbit-Hole\r\n\r\n\r\nAlice was beginning to get very tired of sitting by her sister on the\r\nbank, and of having nothing to do: once or twice she had peeped into\r\nthe book her sister was reading, but it had no pictures or\r\nconversations in it, “and what is the use of a book,” thought Alice\r\n“without pictures or conversations?”\r\n\r\nSo she was considering in her own mind (as well as she could, for the\r\nhot day made her feel very sleepy and stupid), whether the pleasure of\r\nmaking a daisy-chain would be worth the trouble of getting up and\r\npicking the daisies, when suddenly a White Rabbit with pink eyes ran\r\nclose by her.\r\n\r\nThere was nothing so _very_ remarkable in that; nor did Alice think it\r\nso _very_ much out of the way to hear the Rabbit say to itself, “Oh\r\ndear! Oh dear! I shall be late!” (when she thought it over afterwards,\r\nit occurred to her that she ought to have wondered at this, but at the\r\ntime it all seemed quite natural); but when the Rabbit actually _took a\r\nwatch out of its waistcoat-pocket_, and looked at it, and then hurried\r\non, Alice started to her feet, for it flashed across her mind that she\r\nhad never before seen a rabbit with either a waistcoat-pocket, or a\r\nwatch to take out of it, and burning with curiosity, she ran across the\r\nfield after it, and fortunately was just in time to see it pop down a\r\nlarge rabbit-hole under the hedge.\r\n\r\nIn another moment down went Alice after it, never once considering how\r\nin the world she was to get out again.\r\n\r\nThe rabbit-hole went straight on like a tunnel for some way, and then\r\ndipped suddenly down, so suddenly that Alice had not a moment to think\r\nabout stopping herself before she found herself falling down a very\r\ndeep well.\r\n\r\nEither the well was very deep, or she fell very slowly, for she had\r\nplenty of time as she went down to look about her and to wonder what\r\nwas going to happen next. First, she tried to look down and make out\r\nwhat she was coming to, but it was too dark to see anything; then she\r\nlooked at the sides of the well, and noticed that they were filled with\r\ncupboards and book-shelves; here and there she saw maps and pictures\r\nhung upon pegs. She took down a jar from one of the shelves as she\r\npassed; it was labelled “ORANGE MARMALADE”, but to her great\r\ndisappointment it was empty: she did not like to drop the jar for fear\r\nof killing somebody underneath, so managed to put it into one of the\r\ncupboards as she fell past it.\r\n\r\n“Well!” thought Alice to herself, “after such a fall as this, I shall\r\nthink nothing of tumbling down stairs! How brave they’ll all think me\r\nat home! Why, I wouldn’t say anything about it, even if I fell off the\r\ntop of the house!” (Which was very likely true.)\r\n\r\nDown, down, down. Would the fall _never_ come to an end? “I wonder how\r\nmany miles I’ve fallen by this time?” she said aloud. “I must be\r\ngetting somewhere near the centre of the earth. Let me see: that would\r\nbe four thousand miles down, I think—” (for, you see, Alice had learnt\r\nseveral things of this sort in her lessons in the schoolroom, and\r\nthough this was not a _very_ good opportunity for showing off her\r\nknowledge, as the ...

# %% [markdown]
# ## Process Text

# %%
# tokenização

def tokenize(text):
  tokens = nltk.tokenize.word_tokenize(text)
  return tokens

# %%
# Remoção StopWords

def remove_stop_words(tokens):
  result = [i for i in tokens if not i in stop_words]
  result = [e for e in result if e.isalnum()]
  return result

# %%
# Stemming
nltk.download('rslp')
stemmer = nltk.stem.RSLPStemmer()

def stemming(result):
  stemado = [stemmer.stem(i) for i in result]
  # fd = nltk.FreqDist(w.lower() for w in stemado if w not in stop_words)

  return stemado
# Out:
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %%
# prepare pipeline

def prepare_my_data(df, columns):
  for column in columns:
    df[f'{column}_processed'] = df[column] \
      .apply(lambda x: tokenize(x))

    df[f'{column}_processed'] = df[f'{column}_processed'] \
      .apply(lambda x: remove_stop_words(x))

    df[f'{column}_processed'] = df[f'{column}_processed'] \
    .apply(lambda x: stemming(x))

    df[f'{column}_processed'] = df[f'{column}_processed'] \
      .apply(lambda x: ' '.join(x))

  return df

df = prepare_my_data(df_books, ['text'])

# %%
df.head(1)
# Out:
#                               title  \
# 0  Alice’s Adventures in Wonderland
#
#                                           link  \
# 0  https://www.gutenberg.org/files/11/11-0.txt
#
#                                                 text  \
# 0  ALICE’S ADVENTURES IN WONDERLAND ***\r\n\r\n[I...
#
#                                       text_processed
# 0  alic s adventur in wonderland illustration ali...

# %% [markdown]
# ## Modeling

# %% [markdown]
# #### imports

# %%
import tensorflow as tf
from tensorflow import keras

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.layers import Dense, LSTM, Embedding, Bidirectional
from keras.models import Sequential

from tensorflow.keras.optimizers import Adam

# %% [markdown]
# #### Creating a dictionary with all books
#
# * since the size of documents are too long, wi'll be setting a vocubalary with top 1000 words in the entire dataset

# %%
from sklearn.feature_extraction.text import CountVectorizer

def get_top_n_words(corpus, n=None):
    """
    List the top n words in a vocabulary according to occurrence in a text corpus.
    
    get_top_n_words(["I love Python", "Python is a language programming", "Hello world", "I love the world"]) -> 
    [('python', 2),
     ('world', 2),
     ('love', 2),
     ('hello', 1),
     ('is', 1),
     ('programming', 1),
     ('the', 1),
     ('language', 1)]
    """
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
# set the maximun words in dict. It will take the most frequent words

max_words = 1000

tokenizer = Tokenizer()

data = ''.join([i for i in df_books.text])
corpus = data.lower().split(' ')

# filtering top words since we want to train in various documnets
corpus = get_top_n_words(corpus, max_words)
corpus = [i[0] for i in corpus]

tokenizer.fit_on_texts(corpus)

word_index = tokenizer.word_index 
total_words = len(tokenizer.word_index) + 1

# %%
len(word_index)
# Out:
# 998

# %% [markdown]
# #### global helper functions

# %%
# helper function to make sequences of words
max_sequence_len = 4

def make_setences(data, max_seq_len=100):
  corpus = data.lower().split('\n')
  
  input_sequences = []
  for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    
    for i in range(1, len(token_list)):
      n_gram_sequence = token_list[:i+1]
      input_sequences.append(n_gram_sequence) 
  
  input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre'))

  xs = input_sequences[:, :-1]
  labels = input_sequences[:, -1]

  ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)
  return xs, ys

# %%
# helper function to predict new texts
def predict_text():
  input_text = input().strip().lower()
  encoded_text = tokenizer.texts_to_sequences([input_text])[0]
  pad_encoded = pad_sequences([encoded_text], maxlen=max_sequence_len-1, truncating='pre')

  for i in (model.predict(pad_encoded)[0]).argsort()[-3:][::-1]:
    pred_word = tokenizer.index_word[i]
    print("Next word suggestion:", pred_word)

# %%
import matplotlib.pyplot as plt

def plot_loss(history):
  history_dict = history.history
  history_dict.keys()

  acc = history_dict['accuracy']
  val_acc = history_dict['val_accuracy']
  loss = history_dict['loss']
  val_loss = history_dict['val_loss']

  epochs = range(1, len(acc) + 1)

  # "bo" is for "blue dot"
  plt.plot(epochs, loss, 'bo', label='Training loss')
  # b is for "solid blue line"
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()

  plt.show()

# %%
def plot_accuracy(history):
  history_dict = history.history
  history_dict.keys()

  acc = history_dict['accuracy']
  val_acc = history_dict['val_accuracy']
  loss = history_dict['loss']
  val_loss = history_dict['val_loss']
  
  epochs = range(1, len(acc) + 1)

  plt.plot(epochs, acc, 'bo', label='Training acc')
  plt.plot(epochs, val_acc, 'b', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()

  plt.show()

# %% [markdown]
# #### Base Model

# %%
# base model
model = Sequential([
    Embedding(total_words, 240, input_length=max_sequence_len-1),
    Bidirectional(LSTM(75)),
    Dense(total_words, activation='softmax'),
])
adam = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 3, 240)            239760
#
#  bidirectional_2 (Bidirectio  (None, 150)              189600
#  nal)
#
#  dense_2 (Dense)             (None, 999)               150849
#
# =================================================================
# Total params: 580,209
# Trainable params: 580,209
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# #### Training with Alice's Book Model

# %%
# making setences only for alices book
book = 0 

xs, ys = make_setences(df_books.text[book], max_sequence_len)
print(xs.shape, ys.shape)
# Out:
# (16638, 3) (16638, 999)

# %%
history = model.fit(xs, ys, epochs=30, verbose=1)
model.save('alice_model.h5')
# Out:
# Epoch 1/30
# 520/520 [==============================] - 6s 6ms/step - loss: 5.0777 - accuracy: 0.1081
# Epoch 2/30
# 520/520 [==============================] - 3s 6ms/step - loss: 4.4759 - accuracy: 0.1494
# Epoch 3/30
# 520/520 [==============================] - 3s 6ms/step - loss: 4.1409 - accuracy: 0.1735
# Epoch 4/30
# 520/520 [==============================] - 3s 6ms/step - loss: 3.8647 - accuracy: 0.1950
# Epoch 5/30
# 520/520 [==============================] - 3s 6ms/step - loss: 3.6212 - accuracy: 0.2166
# Epoch 6/30
# 520/520 [==============================] - 3s 6ms/step - loss: 3.3955 - accuracy: 0.2408
# Epoch 7/30
# 520/520 [==============================] - 3s 6ms/step - loss: 3.2305 - accuracy: 0.2589
# Epoch 8/30
# 520/520 [==============================] - 3s 6ms/step - loss: 3.0780 - accuracy: 0.2877
# Epoch 9/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.9818 - accuracy: 0.2958
# Epoch 10/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.9136 - accuracy: 0.3089
# Epoch 11/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.8467 - accuracy: 0.3219
# Epoch 12/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.7714 - accuracy: 0.3318
# Epoch 13/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.7032 - accuracy: 0.3461
# Epoch 14/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.6513 - accuracy: 0.3530
# Epoch 15/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.6066 - accuracy: 0.3648
# Epoch 16/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.5811 - accuracy: 0.3725
# Epoch 17/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.5652 - accuracy: 0.3719
# Epoch 18/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.5606 - accuracy: 0.3689
# Epoch 19/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.5626 - accuracy: 0.3722
# Epoch 20/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.5036 - accuracy: 0.3824
# Epoch 21/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.5019 - accuracy: 0.3809
# Epoch 22/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.4509 - accuracy: 0.3893
# Epoch 23/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.4217 - accuracy: 0.3946
# Epoch 24/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.4344 - accuracy: 0.3922
# Epoch 25/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.4678 - accuracy: 0.3855
# Epoch 26/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.4685 - accuracy: 0.3856
# Epoch 27/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.4371 - accuracy: 0.3910
# Epoch 28/30
# 520/520 [==============================] - 4s 7ms/step - loss: 2.4549 - accuracy: 0.3927
# Epoch 29/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.4213 - accuracy: 0.3937
# Epoch 30/30
# 520/520 [==============================] - 3s 6ms/step - loss: 2.3835 - accuracy: 0.4025

# %%
predict_text()
# Out:
# he is not
# Next word suggestion: to
# Next word suggestion: the
# Next word suggestion: this

# %%
predict_text()
# Out:
# she is not
# Next word suggestion: the
# Next word suggestion: to
# Next word suggestion: of

# %%
predict_text()
# Out:
# this is a good
# Next word suggestion: thing
# Next word suggestion: opportunity
# Next word suggestion: character

# %%
predict_text()
# Out:
# today is the
# Next word suggestion: same
# Next word suggestion: thing
# Next word suggestion: mock

# %%
predict_text()
# Out:
# let's take the
# Next word suggestion: and
# Next word suggestion: of
# Next word suggestion: queen

# %% [markdown]
# #### Adding Pride and Judice Book

# %%
from tensorflow import keras
model = keras.models.load_model('/content/alice_model.h5')

# %%
# making setences only for alices book
book = 1 

xs, ys = make_setences(df_books.text[book], max_sequence_len)
print(xs.shape, ys.shape)
# Out:
# (80241, 3) (80241, 999)

# %%
history = model.fit(xs, ys, epochs=30, verbose=1)
model.save('alice__judit_model.h5')
# Out:
# Epoch 1/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 6.3587 - accuracy: 0.0857
# Epoch 2/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.9547 - accuracy: 0.1175
# Epoch 3/30
# 2508/2508 [==============================] - 17s 7ms/step - loss: 4.7399 - accuracy: 0.1237
# Epoch 4/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.6788 - accuracy: 0.1258
# Epoch 5/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.6633 - accuracy: 0.1260
# Epoch 6/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.6387 - accuracy: 0.1246
# Epoch 7/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.6019 - accuracy: 0.1274
# Epoch 8/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5848 - accuracy: 0.1269
# Epoch 9/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5687 - accuracy: 0.1286
# Epoch 10/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5647 - accuracy: 0.1284
# Epoch 11/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5721 - accuracy: 0.1295
# Epoch 12/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5819 - accuracy: 0.1285
# Epoch 13/30
# 2508/2508 [==============================] - 17s 7ms/step - loss: 4.5556 - accuracy: 0.1308
# Epoch 14/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5244 - accuracy: 0.1326
# Epoch 15/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5201 - accuracy: 0.1319
# Epoch 16/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5124 - accuracy: 0.1308
# Epoch 17/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5533 - accuracy: 0.1303
# Epoch 18/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5236 - accuracy: 0.1317
# Epoch 19/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5073 - accuracy: 0.1325
# Epoch 20/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5094 - accuracy: 0.1302
# Epoch 21/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.5152 - accuracy: 0.1316
# Epoch 22/30
# 2508/2508 [==============================] - 17s 7ms/step - loss: 4.5084 - accuracy: 0.1317
# Epoch 23/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.4935 - accuracy: 0.1327
# Epoch 24/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.4914 - accuracy: 0.1334
# Epoch 25/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.4732 - accuracy: 0.1328
# Epoch 26/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.4852 - accuracy: 0.1329
# Epoch 27/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.4770 - accuracy: 0.1329
# Epoch 28/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.4613 - accuracy: 0.1355
# Epoch 29/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.4517 - accuracy: 0.1347
# Epoch 30/30
# 2508/2508 [==============================] - 16s 6ms/step - loss: 4.4687 - accuracy: 0.1350

# %%
predict_text()
# Out:
# he is not
# Next word suggestion: have
# Next word suggestion: know
# Next word suggestion: be

# %%
predict_text()
# Out:
# she is not
# Next word suggestion: know
# Next word suggestion: have
# Next word suggestion: listen

# %%
predict_text()
# Out:
# let me take
# Next word suggestion: it
# Next word suggestion: never
# Next word suggestion: the

# %%
predict_text()
# Out:
# whats next
# Next word suggestion: morning
# Next word suggestion: day
# Next word suggestion: to

# %%
model.save('alice_judit_model.h5')

# %% [markdown]
# #### Adding Frankestein's Book

# %%
from tensorflow import keras
model = keras.models.load_model('/content/alice_judit_model.h5')

# %%
# making setences only for alices book
book = 2

xs, ys = make_setences(df_books.text[book], max_sequence_len)
print(xs.shape, ys.shape)
# Out:
# (44862, 3) (44862, 999)

# %%
history = model.fit(xs, ys, epochs=30, verbose=1)
model.save('alice_judit_frankestein_model.h5')
# Out:
# Epoch 1/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 6.2284 - accuracy: 0.1292
# Epoch 2/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 5.4644 - accuracy: 0.1400
# Epoch 3/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 5.0869 - accuracy: 0.1420
# Epoch 4/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.8353 - accuracy: 0.1443
# Epoch 5/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.6582 - accuracy: 0.1494
# Epoch 6/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.5180 - accuracy: 0.1537
# Epoch 7/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.4170 - accuracy: 0.1561
# Epoch 8/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.3575 - accuracy: 0.1586
# Epoch 9/30
# 1402/1402 [==============================] - 10s 7ms/step - loss: 4.2750 - accuracy: 0.1611
# Epoch 10/30
# 1402/1402 [==============================] - 11s 8ms/step - loss: 4.2260 - accuracy: 0.1642
# Epoch 11/30
# 1402/1402 [==============================] - 10s 7ms/step - loss: 4.1848 - accuracy: 0.1656
# Epoch 12/30
# 1402/1402 [==============================] - 10s 7ms/step - loss: 4.1693 - accuracy: 0.1666
# Epoch 13/30
# 1402/1402 [==============================] - 11s 8ms/step - loss: 4.1521 - accuracy: 0.1635
# Epoch 14/30
# 1402/1402 [==============================] - 12s 9ms/step - loss: 4.1172 - accuracy: 0.1688
# Epoch 15/30
# 1402/1402 [==============================] - 10s 7ms/step - loss: 4.0904 - accuracy: 0.1684
# Epoch 16/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.1087 - accuracy: 0.1706
# Epoch 17/30
# 1402/1402 [==============================] - 10s 7ms/step - loss: 4.1275 - accuracy: 0.1717
# Epoch 18/30
# 1402/1402 [==============================] - 10s 7ms/step - loss: 4.1187 - accuracy: 0.1695
# Epoch 19/30
# 1402/1402 [==============================] - 12s 8ms/step - loss: 4.1111 - accuracy: 0.1697
# Epoch 20/30
# 1402/1402 [==============================] - 11s 8ms/step - loss: 4.0965 - accuracy: 0.1716
# Epoch 21/30
# 1402/1402 [==============================] - 10s 7ms/step - loss: 4.0680 - accuracy: 0.1719
# Epoch 22/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.0781 - accuracy: 0.1726
# Epoch 23/30
# 1402/1402 [==============================] - 13s 9ms/step - loss: 4.0744 - accuracy: 0.1740
# Epoch 24/30
# 1402/1402 [==============================] - 10s 7ms/step - loss: 4.0634 - accuracy: 0.1749
# Epoch 25/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.0540 - accuracy: 0.1753
# Epoch 26/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.0391 - accuracy: 0.1757
# Epoch 27/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.0611 - accuracy: 0.1747
# Epoch 28/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.0791 - accuracy: 0.1729
# Epoch 29/30
# 1402/1402 [==============================] - 9s 6ms/step - loss: 4.0801 - accuracy: 0.1751
# Epoch 30/30
# 1402/1402 [==============================] - 9s 7ms/step - loss: 4.0564 - accuracy: 0.1754

# %%
predict_text()
# Out:
# i love my
# Next word suggestion: father
# Next word suggestion: heart
# Next word suggestion: and

# %%
predict_text()
# Out:
# she is
# Next word suggestion: to
# Next word suggestion: not
# Next word suggestion: the

# %%
predict_text()
# Out:
# he is
# Next word suggestion: to
# Next word suggestion: not
# Next word suggestion: the

# %%
predict_text()
# Out:
# today is good
# Next word suggestion: held
# Next word suggestion: mean
# Next word suggestion: read

# %% [markdown]
# #### Adding The Adventures of Sherlock Holmes Book

# %%
# making setences only for alices book
book = 3

xs, ys = make_setences(df_books.text[book], max_sequence_len)
print(xs.shape, ys.shape)
# Out:
# (64891, 3) (64891, 999)

# %%
history = model.fit(xs, ys, epochs=30, verbose=1)
# Out:
# Epoch 1/30
# 2028/2028 [==============================] - 14s 7ms/step - loss: 7.4132 - accuracy: 0.1032
# Epoch 2/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 6.2247 - accuracy: 0.1167
# Epoch 3/30
# 2028/2028 [==============================] - 14s 7ms/step - loss: 5.6806 - accuracy: 0.1223
# Epoch 4/30
# 2028/2028 [==============================] - 13s 7ms/step - loss: 5.3141 - accuracy: 0.1257
# Epoch 5/30
# 2028/2028 [==============================] - 13s 7ms/step - loss: 5.0732 - accuracy: 0.1282
# Epoch 6/30
# 2028/2028 [==============================] - 14s 7ms/step - loss: 4.8957 - accuracy: 0.1317
# Epoch 7/30
# 2028/2028 [==============================] - 14s 7ms/step - loss: 4.7628 - accuracy: 0.1324
# Epoch 8/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.6693 - accuracy: 0.1351
# Epoch 9/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.6057 - accuracy: 0.1365
# Epoch 10/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.5548 - accuracy: 0.1379
# Epoch 11/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.4934 - accuracy: 0.1396
# Epoch 12/30
# 2028/2028 [==============================] - 14s 7ms/step - loss: 4.4462 - accuracy: 0.1413
# Epoch 13/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.4114 - accuracy: 0.1428
# Epoch 14/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.4069 - accuracy: 0.1450
# Epoch 15/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.4190 - accuracy: 0.1426
# Epoch 16/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3950 - accuracy: 0.1450
# Epoch 17/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3910 - accuracy: 0.1452
# Epoch 18/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3811 - accuracy: 0.1451
# Epoch 19/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3608 - accuracy: 0.1445
# Epoch 20/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3619 - accuracy: 0.1447
# Epoch 21/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3422 - accuracy: 0.1460
# Epoch 22/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3288 - accuracy: 0.1457
# Epoch 23/30
# 2028/2028 [==============================] - 14s 7ms/step - loss: 4.3350 - accuracy: 0.1464
# Epoch 24/30
# 2028/2028 [==============================] - 14s 7ms/step - loss: 4.3467 - accuracy: 0.1454
# Epoch 25/30
# 2028/2028 [==============================] - 16s 8ms/step - loss: 4.3205 - accuracy: 0.1460
# Epoch 26/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.2955 - accuracy: 0.1486
# Epoch 27/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3259 - accuracy: 0.1475
# Epoch 28/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3384 - accuracy: 0.1471
# Epoch 29/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3127 - accuracy: 0.1468
# Epoch 30/30
# 2028/2028 [==============================] - 13s 6ms/step - loss: 4.3055 - accuracy: 0.1489

# %%
predict_text()
# Out:
# i love my
# Next word suggestion: wife
# Next word suggestion: father
# Next word suggestion: surprise

# %%
predict_text()
# Out:
# she is
# Next word suggestion: i
# Next word suggestion: the
# Next word suggestion: to

# %%
predict_text()
# Out:
# he is
# Next word suggestion: to
# Next word suggestion: i
# Next word suggestion: and

# %%
predict_text()
# Out:
# he is not
# Next word suggestion: been
# Next word suggestion: be
# Next word suggestion: know

# %%
predict_text()
# Out:
# she is not
# Next word suggestion: easily
# Next word suggestion: and
# Next word suggestion: the

# %% [markdown]
# #### Adding Robert's Rules Book

# %%
# making setences only for alices book
book = 4

xs, ys = make_setences(df_books.text[book], max_sequence_len)
print(xs.shape, ys.shape)
# Out:
# (24472, 3) (24472, 999)

# %%
history = model.fit(xs, ys, epochs=30, verbose=1)
# Out:
# Epoch 1/30
# 765/765 [==============================] - 5s 6ms/step - loss: 9.2005 - accuracy: 0.1433
# Epoch 2/30
# 765/765 [==============================] - 5s 6ms/step - loss: 6.9922 - accuracy: 0.1688
# Epoch 3/30
# 765/765 [==============================] - 5s 6ms/step - loss: 6.0429 - accuracy: 0.1815
# Epoch 4/30
# 765/765 [==============================] - 5s 6ms/step - loss: 5.4313 - accuracy: 0.1907
# Epoch 5/30
# 765/765 [==============================] - 5s 6ms/step - loss: 5.0181 - accuracy: 0.1973
# Epoch 6/30
# 765/765 [==============================] - 5s 6ms/step - loss: 4.7120 - accuracy: 0.2050
# Epoch 7/30
# 765/765 [==============================] - 5s 6ms/step - loss: 4.4871 - accuracy: 0.2118
# Epoch 8/30
# 765/765 [==============================] - 5s 6ms/step - loss: 4.3129 - accuracy: 0.2145
# Epoch 9/30
# 765/765 [==============================] - 7s 9ms/step - loss: 4.1741 - accuracy: 0.2204
# Epoch 10/30
# 765/765 [==============================] - 6s 8ms/step - loss: 4.0443 - accuracy: 0.2233
# Epoch 11/30
# 765/765 [==============================] - 5s 7ms/step - loss: 3.9229 - accuracy: 0.2287
# Epoch 12/30
# 765/765 [==============================] - 6s 8ms/step - loss: 3.8256 - accuracy: 0.2344
# Epoch 13/30
# 765/765 [==============================] - 6s 7ms/step - loss: 3.7736 - accuracy: 0.2378
# Epoch 14/30
# 765/765 [==============================] - 5s 7ms/step - loss: 3.6999 - accuracy: 0.2368
# Epoch 15/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.6420 - accuracy: 0.2424
# Epoch 16/30
# 765/765 [==============================] - 5s 7ms/step - loss: 3.5988 - accuracy: 0.2448
# Epoch 17/30
# 765/765 [==============================] - 8s 10ms/step - loss: 3.5654 - accuracy: 0.2491
# Epoch 18/30
# 765/765 [==============================] - 7s 9ms/step - loss: 3.5344 - accuracy: 0.2502
# Epoch 19/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.4945 - accuracy: 0.2529
# Epoch 20/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.4730 - accuracy: 0.2529
# Epoch 21/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.4704 - accuracy: 0.2558
# Epoch 22/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.4403 - accuracy: 0.2575
# Epoch 23/30
# 765/765 [==============================] - 6s 7ms/step - loss: 3.4105 - accuracy: 0.2589
# Epoch 24/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.3976 - accuracy: 0.2617
# Epoch 25/30
# 765/765 [==============================] - 5s 7ms/step - loss: 3.3933 - accuracy: 0.2599
# Epoch 26/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.3805 - accuracy: 0.2622
# Epoch 27/30
# 765/765 [==============================] - 5s 7ms/step - loss: 3.3978 - accuracy: 0.2594
# Epoch 28/30
# 765/765 [==============================] - 5s 7ms/step - loss: 3.3788 - accuracy: 0.2639
# Epoch 29/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.3554 - accuracy: 0.2627
# Epoch 30/30
# 765/765 [==============================] - 5s 6ms/step - loss: 3.3418 - accuracy: 0.2670

# %%
predict_text()
# Out:
# i love my
# Next word suggestion: order
# Next word suggestion: point
# Next word suggestion: find

# %%
predict_text()
# Out:
# she sad to
# Next word suggestion: the
# Next word suggestion: reconsider
# Next word suggestion: adjourn

# %%
predict_text()
# Out:
# he sad to
# Next word suggestion: the
# Next word suggestion: be
# Next word suggestion: adjourn

# %%
predict_text()
# Out:
# my name is
# Next word suggestion: put
# Next word suggestion: etc
# Next word suggestion: before

# %% [markdown]
# #### Fitting one more time with all books

# %%
# making setences only for alices book
xs, ys = make_setences(''. join([i for i in df_books.text]), max_sequence_len)
print(xs.shape, ys.shape)
# Out:
# (231107, 3) (231107, 999)

# %%
history = model.fit(xs, ys, epochs=30, verbose=1)
model.save('all_books_final.h5')
# Out:
# Epoch 1/30
# 7223/7223 [==============================] - 51s 7ms/step - loss: 7.3396 - accuracy: 0.0984
# Epoch 2/30
# 7223/7223 [==============================] - 50s 7ms/step - loss: 5.7270 - accuracy: 0.1126
# Epoch 3/30
# 7223/7223 [==============================] - 47s 7ms/step - loss: 5.3700 - accuracy: 0.1159
# Epoch 4/30
# 7223/7223 [==============================] - 54s 8ms/step - loss: 5.2085 - accuracy: 0.1181
# Epoch 5/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.1313 - accuracy: 0.1194
# Epoch 6/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.0726 - accuracy: 0.1216
# Epoch 7/30
# 7223/7223 [==============================] - 50s 7ms/step - loss: 5.0305 - accuracy: 0.1222
# Epoch 8/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.0176 - accuracy: 0.1215
# Epoch 9/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.0083 - accuracy: 0.1217
# Epoch 10/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.0005 - accuracy: 0.1217
# Epoch 11/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 4.9953 - accuracy: 0.1224
# Epoch 12/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 4.9919 - accuracy: 0.1212
# Epoch 13/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 4.9890 - accuracy: 0.1222
# Epoch 14/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.0157 - accuracy: 0.1217
# Epoch 15/30
# 7223/7223 [==============================] - 49s 7ms/step - loss: 5.0000 - accuracy: 0.1213
# Epoch 16/30
#  926/7223 [==>...........................] - ETA: 39s - loss: 4.8317 - accuracy: 0.1268
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-2175856d9ebf> in <module>
# ----> 1 history = model.fit(xs, ys, epochs=30, verbose=1)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
predict_text()
# Out:
# i love my
# Next word suggestion: friend
# Next word suggestion: dear
# Next word suggestion: and

# %%
predict_text()
# Out:
# she sad to
# Next word suggestion: the
# Next word suggestion: be
# Next word suggestion: her

# %%
predict_text()
# Out:
# he sad to
# Next word suggestion: the
# Next word suggestion: be
# Next word suggestion: her

# %%
predict_text()
# Out:
# i'm good in
# Next word suggestion: the
# Next word suggestion: my
# Next word suggestion: his

# %% [markdown]
# #### trying a simple model

# %%
from keras.layers import Dense, LSTM, Embedding, Bidirectional
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam

model_1 = Sequential([
    Embedding(total_words, 32, input_length=max_sequence_len-1),
    LSTM(16),
    Dense(total_words, activation='softmax'),
])
adam = Adam(lr=0.01)
model_1.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 3, 32)             31968
#
#  lstm_3 (LSTM)               (None, 16)                3136
#
#  dense_3 (Dense)             (None, 999)               16983
#
# =================================================================
# Total params: 52,087
# Trainable params: 52,087
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history_1 = model_1.fit(xs, ys, epochs=30, verbose=1)
# Out:
# Epoch 1/30
# 7223/7223 [==============================] - 36s 5ms/step - loss: 4.9337 - accuracy: 0.1274
# Epoch 2/30
# 7223/7223 [==============================] - 35s 5ms/step - loss: 4.7179 - accuracy: 0.1445
# Epoch 3/30
# 7223/7223 [==============================] - 36s 5ms/step - loss: 4.6749 - accuracy: 0.1467
# Epoch 4/30
# 7223/7223 [==============================] - 35s 5ms/step - loss: 4.6585 - accuracy: 0.1474
# Epoch 5/30
# 7223/7223 [==============================] - 35s 5ms/step - loss: 4.6514 - accuracy: 0.1484
# Epoch 6/30
# 7223/7223 [==============================] - 35s 5ms/step - loss: 4.6445 - accuracy: 0.1486
# Epoch 7/30
# 7223/7223 [==============================] - 36s 5ms/step - loss: 4.6390 - accuracy: 0.1486
# Epoch 8/30
# 7223/7223 [==============================] - 37s 5ms/step - loss: 4.6380 - accuracy: 0.1493
# Epoch 9/30
# 6395/7223 [=========================>....] - ETA: 4s - loss: 4.6379 - accuracy: 0.1482
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-dad3df5d3217> in <module>
# ----> 1 history_1 = model_1.fit(xs, ys, epochs=30, verbose=1)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1105       # Only block async when verbose = 1.
#    1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#    1109   def _finalize_progbar(self, logs, counter):
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     974
#     975       message += info
# --> 976       io_utils.print_msg(message, line_break=False)
#     977       message = ''
#     978
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/io_utils.py in print_msg(message, line_break)
#      36     else:
#      37       sys.stdout.write(message)
# ---> 38     sys.stdout.flush()
#      39
#      40
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in flush(self)
#     342         if self.pub_thread and self.pub_thread.thread is not None and self.pub_thread.thread.is_alive():
#     343             # request flush on the background thread
# --> 344             self.pub_thread.schedule(self._flush)
#     345             # wait for flush to actually get through, if we can.
#     346             # waiting across threads during import can cause deadlocks
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# helper function to predict new texts
def predict_text_1():
  input_text = input().strip().lower()
  encoded_text = tokenizer.texts_to_sequences([input_text])[0]
  pad_encoded = pad_sequences([encoded_text], maxlen=max_sequence_len-1, truncating='pre')

  for i in (model_1.predict(pad_encoded)[0]).argsort()[-3:][::-1]:
    pred_word = tokenizer.index_word[i]
    print("Next word suggestion:", pred_word)

predict_text_1()
# Out:
# she is
# Next word suggestion: to
# Next word suggestion: in
# Next word suggestion: not

# %%
predict_text_1()
# Out:
# he is
# Next word suggestion: to
# Next word suggestion: in
# Next word suggestion: not

# %%
predict_text_1()
# Out:
# tomorow wi'll be
# Next word suggestion: to
# Next word suggestion: in
# Next word suggestion: the

# %%
predict_text_1()
# Out:
# my friend have
# Next word suggestion: been
# Next word suggestion: the
# Next word suggestion: to

# %% [markdown]
# #### Trying a roubust model

# %%
from keras.layers import Dense, LSTM, Embedding, Bidirectional
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam

model_2 = Sequential([
    Embedding(total_words, 240, input_length=max_sequence_len-1),
    Bidirectional(LSTM(150)),
    Dense(300, activation='relu'),
    Dense(total_words, activation='softmax'),
])
adam = Adam(lr=0.01)
model_2.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
model_2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 3, 240)            239760
#
#  bidirectional_3 (Bidirectio  (None, 300)              469200
#  nal)
#
#  dense_4 (Dense)             (None, 300)               90300
#
#  dense_5 (Dense)             (None, 999)               300699
#
# =================================================================
# Total params: 1,099,959
# Trainable params: 1,099,959
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history_2 = model_2.fit(xs, ys, epochs=30, verbose=1)
# Out:
# Epoch 1/30
# 7223/7223 [==============================] - 52s 7ms/step - loss: 5.1592 - accuracy: 0.1006
# Epoch 2/30
# 7223/7223 [==============================] - 48s 7ms/step - loss: 5.0642 - accuracy: 0.1005
# Epoch 3/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.0914 - accuracy: 0.0973
# Epoch 4/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.1197 - accuracy: 0.0950
# Epoch 5/30
# 7223/7223 [==============================] - 47s 7ms/step - loss: 5.1305 - accuracy: 0.0955
# Epoch 6/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.1538 - accuracy: 0.0930
# Epoch 7/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.1580 - accuracy: 0.0922
# Epoch 8/30
# 7223/7223 [==============================] - 47s 7ms/step - loss: 5.1821 - accuracy: 0.0920
# Epoch 9/30
# 7223/7223 [==============================] - 50s 7ms/step - loss: 5.1901 - accuracy: 0.0913
# Epoch 10/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.2060 - accuracy: 0.0901
# Epoch 11/30
# 7223/7223 [==============================] - 47s 7ms/step - loss: 5.2076 - accuracy: 0.0912
# Epoch 12/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.2202 - accuracy: 0.0895
# Epoch 13/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.2294 - accuracy: 0.0890
# Epoch 14/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.2361 - accuracy: 0.0886
# Epoch 15/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.2544 - accuracy: 0.0873
# Epoch 16/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.2618 - accuracy: 0.0877
# Epoch 17/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.2682 - accuracy: 0.0877
# Epoch 18/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.2755 - accuracy: 0.0869
# Epoch 19/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.2899 - accuracy: 0.0872
# Epoch 20/30
# 7223/7223 [==============================] - 47s 7ms/step - loss: 5.2903 - accuracy: 0.0873
# Epoch 21/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.2976 - accuracy: 0.0869
# Epoch 22/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.3007 - accuracy: 0.0880
# Epoch 23/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.3081 - accuracy: 0.0876
# Epoch 24/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.3129 - accuracy: 0.0872
# Epoch 25/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.3201 - accuracy: 0.0866
# Epoch 26/30
# 7223/7223 [==============================] - 47s 7ms/step - loss: 5.3258 - accuracy: 0.0864
# Epoch 27/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.3362 - accuracy: 0.0863
# Epoch 28/30
# 7223/7223 [==============================] - 46s 6ms/step - loss: 5.3382 - accuracy: 0.0863
# Epoch 29/30
# 7223/7223 [==============================] - 47s 7ms/step - loss: 5.3399 - accuracy: 0.0862
# Epoch 30/30
# 7223/7223 [==============================] - 47s 6ms/step - loss: 5.3489 - accuracy: 0.0852

# %% [markdown]
# ## Conclusions:
#
# * small books have a better accuracy than larger books
# * memory was a problem, so i have to limit the maximum words in dictionary
# * the roubust model is worse than the simplest model
